# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
ρ = 0.1 # initialize ro
n = 1000 # sample size
p = 20 # dimension

# %%
def generate_dataset(n, p, ρ, r, β, duplication):
    X = torch.zeros((duplication, n, p))
    i = torch.arange(p).view(-1, 1)
    j = torch.arange(p).view(1, -1)
    
    Σ = torch.pow(ρ, torch.abs(i - j).float())
    L = torch.linalg.cholesky(Σ)
    Z = torch.randn(duplication, n, p)
    X = Z @ torch.transpose(L, 1, 0)
    
    σ = (1-r)/r * (β.T @ Σ @ β)
    
    ε = torch.randn(n) * torch.sqrt(σ)
    
    Y = X @ β + ε
    
    return X, Y, {
        'Σ': Σ,
        'ε': ε
    }

# %%
X, Y, other = generate_dataset(n=100, p=10, ρ=0, β=torch.ones(10), r=0.8, duplication=1000)
# Out:
# /tmp/ipykernel_388202/253544527.py:11: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3683.)
#   σ = (1-r)/r * (β.T @ Σ @ β)

# %%
from torch import nn

xtx = X.permute(0, 2, 1)@X

# %%
xtx.shape
# Out:
# torch.Size([1000, 10, 10])

# %%
Y = Y.unsqueeze(-1)

# %%
from torch.optim import Adam, SGD
from torch.nn.functional import mse_loss, l1_loss
from tqdm import tqdm

with torch.no_grad():
    β_ols = torch.linalg.pinv(X) @ Y  # Initial OLS estimates
    weights = 1 / (β_ols.abs() + 1e-5)  # Adaptive weights
    wtw = weights.permute(0, 2, 1) @ weights  # W^T W

def lasso(λ, epochs=200, lr=0.025, adaptive=False, wtw=wtw, weights=weights):
    p = X.shape[-1]
    β = torch.randn((1000, p, 1), device='cuda', requires_grad=True)
    optimizer = Adam([β], lr=lr)
    loss_l = torch.zeros(epochs)
    ones = torch.ones((1000, 1), device='cuda')
    # pbar = tqdm(total=epochs, desc='LASSO')
    for epoch in range(epochs):
        optimizer.zero_grad()
        mse = torch.mean(((Y-X@β)**2), dim=1)
        l1norm = torch.sum(β.abs(), dim=1)
        # print(mse.shape, l1norm.shape)
        loss = mse + λ*l1norm
        loss.backward(ones)
        loss_l[epoch] = loss[-1]
        # pbar.set_postfix_str(f'loss: {loss}')
        # pbar.update()
        optimizer.step()
    # rss = torch.sum(((Y-X@β)**2), dim=1).squeeze(-1)
    mse = torch.mean(((Y-X@β)**2), dim=1).flatten()
    # k = (β.abs() > 1e-5).sum()
    k = 100
    aic = 100 * torch.log(mse*0.01) + torch.full(size=(1000, ), fill_value=2*k, device='cuda')
    bic = 100 * torch.log(mse*0.01) + torch.full(size=(1000, ), fill_value=torch.log(torch.tensor(100))*k, device='cuda')
    
    return β, aic, bic, mse, loss_l

# %%
def adaptive_lasso(λ, epochs=200, lr = 0.025, adaptive=False, wtw=wtw, weights=weights):
    p = X.shape[-1]
    β = torch.randn((1000, p, 1), device='cuda', requires_grad=True)
    optimizer = Adam([β], lr=lr)
    loss_l = torch.zeros(epochs, device='cuda')
    ones = torch.ones((1000, 1), device='cuda')

    # with torch.no_grad():
    #     β_ols = torch.linalg.pinv(X) @ Y  # Initial OLS estimates
    #     weights = 1 / (β_ols.abs() + 1e-5)  # Adaptive weights
    # global weights
    if weights.device != 'cuda':
        weights = weights.cuda()
    
    for epoch in range(epochs):
        optimizer.zero_grad()
        mse = torch.mean(((Y - X @ β) ** 2), dim=1)
        l1norm = torch.sum(weights * β.abs(), dim=1)  # Adaptive L1 penalty
        loss = mse + λ * l1norm
        loss.backward(ones)
        loss_l[epoch] = loss[-1]
        optimizer.step()
    
    # rss = torch.sum(((Y - X @ β) ** 2), dim=1).squeeze(-1)
    mse = torch.mean(((Y - X @ β) ** 2), dim=1).flatten()
    # k = (β.abs() > 1e-5).sum()
    k = 100
    aic = 100 * torch.log(mse * 0.01) + torch.full(size=(1000,), fill_value=2 * k, device='cuda')
    bic = 100 * torch.log(mse * 0.01) + torch.full(size=(1000,), fill_value=torch.log(torch.tensor(100)) * k, device='cuda')
    
    return β, aic, bic, mse, loss_l

# %%
def ridge(λ, adaptive=False, wtw=wtw, weights=weights):
    # closed form solution
    
    global X, xtx, Y
    if xtx.device != 'cuda':
        xtx = xtx.to('cuda')
    if Y.device != 'cuda':
        Y = Y.to('cuda')
    if X.device != 'cuda':
        X = X.to('cuda')
    try:
        β = torch.linalg.solve(xtx + λ * torch.eye(xtx.shape[-1], device='cuda'), X.permute(0, 2, 1)@Y)
    except:
        # β = torch.linalg.pinv(xtx + λ * torch.eye(xtx.shape[-1], device='cuda')) @ X.permute(0, 2, 1)@Y
        # add a small value to lambda
        β = torch.linalg.solve(xtx + (λ + 1e-5) * torch.eye(xtx.shape[-1], device='cuda'), X.permute(0, 2, 1)@Y)
    
    # use pinv
    # β = torch.linalg.pinv(xtx + λ * torch.eye(xtx.shape[-1], device='cuda')) @ X.permute(0, 2, 1)@Y
    
    
    # report AIC, BIC
    # rss = torch.sum(((Y-X@β)**2), dim=1).squeeze(-1)
    mse = torch.mean(((Y-X@β)**2), dim=1).flatten()
    # k = (β.abs() > 1e-5).sum()
    k = 100
    aic = 100 * torch.log(mse) + torch.full(size=(1000, ), fill_value=2*k, device='cuda')
    bic = 100 * torch.log(mse) + torch.full(size=(1000, ), fill_value=torch.log(torch.tensor(100))*k, device='cuda')
    
    return β, aic, bic, mse

# %%
def ridge_adaptive(λ, adaptive=True, wtw=wtw, weights=weights):
    global X, xtx, Y
    if xtx.device != 'cuda':
        xtx = xtx.to('cuda')
    if Y.device != 'cuda':
        Y = Y.to('cuda')
    if X.device != 'cuda':
        X = X.to('cuda')
    
    # global wtw
    if wtw.device != 'cuda':
        wtw = wtw.to('cuda')
    
    try:
        β = torch.linalg.solve(xtx + λ * wtw, X.permute(0, 2, 1) @ Y)
    except:
        # add purturbation to lambda
        β = torch.linalg.pinv(xtx + (λ+1e-5) * wtw) @ X.permute(0, 2, 1) @ Y
    # use pinv
    # β = torch.linalg.pinv(xtx + λ * wtw) @ X.permute(0, 2, 1) @ Y
    
    # rss = torch.sum(((Y - X @ β) ** 2), dim=1).squeeze(-1)
    mse = torch.mean(((Y - X @ β) ** 2), dim=1).flatten()
    # k = (β.abs() > 1e-5).sum()
    k = 100
    aic = 100 * torch.log(mse) + torch.full(size=(1000,), fill_value=2 * k, device='cuda')
    bic = 100 * torch.log(mse) + torch.full(size=(1000,), fill_value=torch.log(torch.tensor(100)) * k, device='cuda')
    
    return β, aic, bic, mse

# %%
def loo_cv(model, λ, adaptive=False, weights=weights, wtw=wtw):
    global X, Y
    n = X.shape[1]
    rss = torch.zeros((1000, n), device='cuda')
    # for i in tqdm(range(n)):
    for i in range(n):
        X_ = torch.cat((X[:, :i], X[:, i+1:]), dim=1)
        Y_ = torch.cat((Y[:, :i], Y[:, i+1:]), dim=1)
        res = model(λ, adaptive=adaptive, weights=weights, wtw=wtw)
        match res:
            case (β, _, _, mse):
                β, _, _, mse = res
            case (β, _, _, mse, loss):
                β, _, _, mse, loss = res
        # rss[:, i] = torch.sum(((Y_ - X_ @ β) ** 2), dim=1).squeeze(-1)
        if mse.dim() == 1:
            mse = mse.unsqueeze(-1)
        rss[:, i] = torch.mean(mse, dim=1)
    mse = model(λ, adaptive=adaptive, weights=weights, wtw=wtw)[3]
    
    return torch.mean(rss, dim=1), mse

# %%
# print("Using model: ridge")
# loo_cv(ridge, 0.1)

# print("Using model: ridge_adaptive")
# loo_cv(ridge_adaptive, 0.1)

# print("Using model: lasso")
# loo_cv(lasso, 0.1)

# print("Using model: adaptive_lasso")
# loo_cv(adaptive_lasso, 0.1)

# %%
a = loo_cv(ridge, 0.1)
a[0].shape, a[1].shape
# Out:
# (torch.Size([1000]), torch.Size([1000]))

# %%
def put_together(n, p, rho, beta, wtw, weights):
    global X, Y, xtx
    X, Y, _ = generate_dataset(n, p, rho, 0.8, beta, 1000)
    if len(Y.shape) == 2:
        Y = Y.unsqueeze(-1)
    xtx = X.permute(0, 2, 1) @ X

    # print(X.shape, Y.shape, xtx.shape)

    # aic, bic, loocv mat
    best_ridge_aic = torch.full((1000,), float('inf'), device='cuda')
    best_ridge_adaptive_aic = torch.full((1000,), float('inf'), device='cuda')
    best_lasso_aic = torch.full((1000,), float('inf'), device='cuda')
    best_lasso_adaptive_aic = torch.full((1000,), float('inf'), device='cuda')

    best_ridge_aic_mse = torch.full((1000,), float('inf'), device='cuda')
    best_ridge_adaptive_aic_mse = torch.full((1000,), float('inf'), device='cuda')
    best_lasso_aic_mse = torch.full((1000,), float('inf'), device='cuda')
    best_lasso_adaptive_aic_mse = torch.full((1000,), float('inf'), device='cuda')

    best_ridge_bic = torch.full((1000,), float('inf'), device='cuda')
    best_ridge_adaptive_bic = torch.full((1000,), float('inf'), device='cuda')
    best_lasso_bic = torch.full((1000,), float('inf'), device='cuda')
    best_lasso_adaptive_bic = torch.full((1000,), float('inf'), device='cuda')

    best_ridge_bic_mse = torch.full((1000,), float('inf'), device='cuda')
    best_ridge_adaptive_bic_mse = torch.full((1000,), float('inf'), device='cuda')
    best_lasso_bic_mse = torch.full((1000,), float('inf'), device='cuda')
    best_lasso_adaptive_bic_mse = torch.full((1000,), float('inf'), device='cuda')

    best_ridge_loocv = torch.full((1000,), float('inf'), device='cuda')
    best_ridge_adaptive_loocv = torch.full((1000,), float('inf'), device='cuda')
    best_lasso_loocv = torch.full((1000,), float('inf'), device='cuda')
    best_lasso_adaptive_loocv = torch.full((1000,), float('inf'), device='cuda')
    best_ridge_loocv_mse = torch.full((1000,), float('inf'), device='cuda')
    best_ridge_adaptive_loocv_mse = torch.full((1000,), float('inf'), device='cuda')
    best_lasso_loocv_mse = torch.full((1000,), float('inf'), device='cuda')
    best_lasso_adaptive_loocv_mse = torch.full((1000,), float('inf'), device='cuda')
    
    pbar = tqdm(total=10, desc='λ')
    pbar.update(0)
    for i,λ in enumerate(torch.linspace(0, 0.5, 10)):
        β_ridge, aic_ridge, bic_ridge, mse_ridge = ridge(λ, adaptive=False, wtw=wtw, weights=weights)
        β_ridge_adaptive, aic_ridge_adaptive, bic_ridge_adaptive, mse_ridge_adaptive = ridge_adaptive(λ, adaptive=True, wtw=wtw, weights=weights)
        β_lasso, aic_lasso, bic_lasso, mse_lasso, loss_lasso = lasso(λ, adaptive=False, wtw=wtw, weights=weights)
        β_adaptive_lasso, aic_adaptive_lasso, bic_adaptive_lasso, mse_adaptive_lasso, loss_adaptive_lasso = adaptive_lasso(λ, adaptive=True, wtw=wtw, weights=weights)

        # print('loocv')

        # loocv
        loocv_ridge, mse_ridge = loo_cv(ridge, λ, False, weights, wtw)
        loocv_ridge_adaptive, mse_ridge_adaptive = loo_cv(ridge_adaptive, λ, True, weights, wtw)
        loocv_lasso, mse_lasso = loo_cv(lasso, λ, False, weights, wtw)
        loocv_adaptive_lasso, mse_adaptive_lasso = loo_cv(adaptive_lasso, λ, True, weights, wtw)


        # index for improved loocv ridge
        ridge_better_ind = loocv_ridge < best_ridge_loocv

        # update the best loocv and loocv mse
        best_ridge_loocv[ridge_better_ind] = loocv_ridge[ridge_better_ind]
        best_ridge_loocv_mse[ridge_better_ind] = mse_ridge[ridge_better_ind]


        # index for improved loocv adaptive ridge
        ridge_adaptive_better_ind = loocv_ridge_adaptive < best_ridge_adaptive_loocv

        # update the best loocv and loocv mse
        best_ridge_adaptive_loocv[ridge_adaptive_better_ind] = loocv_ridge_adaptive[ridge_adaptive_better_ind]
        best_ridge_adaptive_loocv_mse[ridge_adaptive_better_ind] = mse_ridge_adaptive[ridge_adaptive_better_ind]

        # index for improved loocv lasso
        lasso_better_ind = loocv_lasso < best_lasso_loocv

        # update the best loocv and loocv mse
        best_lasso_loocv[lasso_better_ind] = loocv_lasso[lasso_better_ind]
        best_lasso_loocv_mse[lasso_better_ind] = mse_lasso[lasso_better_ind]


        # index for improved loocv adaptive lasso
        adaptive_lasso_better_ind = loocv_adaptive_lasso < best_lasso_adaptive_loocv

        # update the best loocv and loocv mse
        best_lasso_adaptive_loocv[adaptive_lasso_better_ind] = loocv_adaptive_lasso[adaptive_lasso_better_ind]
        best_lasso_adaptive_loocv_mse[adaptive_lasso_better_ind] = mse_adaptive_lasso[adaptive_lasso_better_ind]


        # the indexes of which aic is smaller than the previous aic
        ridge_better_ind = aic_ridge < best_ridge_aic
        # print(ridge_better_ind.shape, ridge_better_ind)
        # update the best aic and aic mse
        best_ridge_aic[ridge_better_ind] = aic_ridge[ridge_better_ind]
        best_ridge_aic_mse[ridge_better_ind] = mse_ridge[ridge_better_ind]

        # best aic for adaptive ridge
        ridge_adaptive_better_ind = torch.where(aic_ridge_adaptive < best_ridge_adaptive_aic)

        best_ridge_adaptive_aic[ridge_adaptive_better_ind] = aic_ridge_adaptive[ridge_adaptive_better_ind]
        best_ridge_adaptive_aic_mse[ridge_adaptive_better_ind] = mse_ridge_adaptive[ridge_adaptive_better_ind]

        # best aic for lasso
        lasso_better_ind = aic_lasso < best_lasso_aic
        best_lasso_aic[lasso_better_ind] = aic_lasso[lasso_better_ind]
        best_lasso_aic_mse[lasso_better_ind] = mse_lasso[lasso_better_ind]

        # best aic for adaptive lasso   
        adaptive_lasso_better_ind = aic_adaptive_lasso < best_lasso_adaptive_aic

        best_lasso_adaptive_aic[adaptive_lasso_better_ind] = aic_adaptive_lasso[adaptive_lasso_better_ind]
        best_lasso_adaptive_aic_mse[adaptive_lasso_better_ind] = mse_adaptive_lasso[adaptive_lasso_better_ind]

        # best bic for ridge
        ridge_better_ind = bic_ridge < best_ridge_bic

        best_ridge_bic[ridge_better_ind] = bic_ridge[ridge_better_ind]
        best_ridge_bic_mse[ridge_better_ind] = mse_ridge[ridge_better_ind]

        # best bic for adaptive ridge
        ridge_adaptive_better_ind = bic_ridge_adaptive < best_ridge_adaptive_bic

        best_ridge_adaptive_bic[ridge_adaptive_better_ind] = bic_ridge_adaptive[ridge_adaptive_better_ind]
        best_ridge_adaptive_bic_mse[ridge_adaptive_better_ind] = mse_ridge_adaptive[ridge_adaptive_better_ind]

        # best bic for lasso
        lasso_better_ind = bic_lasso < best_lasso_bic

        best_lasso_bic[lasso_better_ind] = bic_lasso[lasso_better_ind]
        best_lasso_bic_mse[lasso_better_ind] = mse_lasso[lasso_better_ind]

        # best bic for adaptive lasso
        adaptive_lasso_better_ind = bic_adaptive_lasso < best_lasso_adaptive_bic

        best_lasso_adaptive_bic[adaptive_lasso_better_ind] = bic_adaptive_lasso[adaptive_lasso_better_ind]
        best_lasso_adaptive_bic_mse[adaptive_lasso_better_ind] = mse_adaptive_lasso[adaptive_lasso_better_ind]

        pbar.update(1)
        pbar.set_postfix_str(f'λ: {λ}')

    # now we have the best mses for aic and bic
    # output the average best mse for all cases
    # return torch.mean(best_ridge_aic_mse), torch.mean(best_ridge_adaptive_aic_mse), torch.mean(best_lasso_aic_mse), torch.mean(best_lasso_adaptive_aic_mse), torch.mean(best_ridge_bic_mse), torch.mean(best_ridge_adaptive_bic_mse), torch.mean(best_lasso_bic_mse), torch.mean(best_lasso_adaptive_bic_mse)
    return {
        'ridge_aic': torch.mean(best_ridge_aic_mse),
        'ridge_adaptive_aic': torch.mean(best_ridge_adaptive_aic_mse),
        'lasso_aic': torch.mean(best_lasso_aic_mse),
        'lasso_adaptive_aic': torch.mean(best_lasso_adaptive_aic_mse),
        'ridge_bic': torch.mean(best_ridge_bic_mse),
        'ridge_adaptive_bic': torch.mean(best_ridge_adaptive_bic_mse),
        'lasso_bic': torch.mean(best_lasso_bic_mse),
        'lasso_adaptive_bic': torch.mean(best_lasso_adaptive_bic_mse),
        'ridge_loocv': torch.mean(best_ridge_loocv_mse),
        'ridge_adaptive_loocv': torch.mean(best_ridge_adaptive_loocv_mse),
        'lasso_loocv': torch.mean(best_lasso_loocv_mse),
        'lasso_adaptive_loocv': torch.mean(best_lasso_adaptive_loocv_mse)
    }

# %%
# ans1 = put_together(100, 10, 0.1, torch.ones(10))

# %%
def experiments():
    n = 100
    ps = [50, 25, 10]
    ρs = [0, 0.25, 0.5]
    
    global X, Y
    
    results = {}
    for p in ps:
        β_sparse = torch.zeros((p))
        β_dense = torch.ones((p))
        β_sparse[:int(p**0.5)] = 2 / p**0.5
        β_dense[:] = 5 / torch.arange(1, p+1).float().sqrt()
        
        for ρ in ρs:
            X, Y, _ = generate_dataset(n, p, 0, 0.8, β_sparse, 1000)
            xtx = X.permute(0, 2, 1)@X
            with torch.no_grad():
                # β_ols = torch.linalg.pinv(X) @ Y  # Initial OLS estimates
                β_ols = torch.linalg.lstsq(X, Y).solution
                weights = 1 / (β_ols.abs() + 1e-5)  # Adaptive weights
                if weights.dim() == 2:
                    weights = weights.unsqueeze(-1)
                wtw = weights.permute(0, 2, 1)@weights
            results[f'{n=}_{p=}_{ρ=}_sparse'] = put_together(n, p, 0, β_sparse, wtw, weights)
            results[f'{n=}_{p=}_{ρ=}_dense'] = put_together(n, p, 0, β_dense, wtw, weights)
            
    return results

# %%
results = experiments()
# Out:
# λ: 100%|██████████| 10/10 [26:31<00:00, 159.16s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [17:25<00:00, 104.55s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [38:09<00:00, 228.92s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [34:02<00:00, 204.25s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [32:00<00:00, 192.10s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [32:06<00:00, 192.69s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [13:57<00:00, 83.80s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [13:57<00:00, 83.75s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [14:08<00:00, 84.87s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [13:58<00:00, 83.89s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [14:01<00:00, 84.17s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [13:50<00:00, 83.00s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [13:49<00:00, 82.95s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [13:43<00:00, 82.30s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [13:19<00:00, 79.93s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [12:23<00:00, 74.35s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [12:46<00:00, 76.63s/it, λ: 0.5]
# λ: 100%|██████████| 10/10 [12:43<00:00, 76.38s/it, λ: 0.5]

# %%
results
# Out:
# {'n=100_p=50_ρ=0_sparse': {'ridge_aic': tensor(0.0721, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(0.0721, device='cuda:0'),
#   'lasso_aic': tensor(0.1603, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(0.1773, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(0.0721, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(0.0721, device='cuda:0'),
#   'lasso_bic': tensor(0.1603, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(0.1773, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(0.0721, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(0.0721, device='cuda:0'),
#   'lasso_loocv': tensor(0.1463, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(0.1694, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=50_ρ=0_dense': {'ridge_aic': tensor(15.5376, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(15.5376, device='cuda:0'),
#   'lasso_aic': tensor(20.7056, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(20.1790, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(15.5376, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(15.5376, device='cuda:0'),
#   'lasso_bic': tensor(20.7056, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(20.1790, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(15.5376, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(15.5376, device='cuda:0'),
#   'lasso_loocv': tensor(20.4038, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(20.1790, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=50_ρ=0.25_sparse': {'ridge_aic': tensor(0.0629, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(0.0629, device='cuda:0'),
#   'lasso_aic': tensor(0.1465, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(0.1688, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(0.0629, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(0.0629, device='cuda:0'),
#   'lasso_bic': tensor(0.1465, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(0.1688, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(0.0629, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(0.0629, device='cuda:0'),
#   'lasso_loocv': tensor(0.1328, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(0.1605, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=50_ρ=0.25_dense': {'ridge_aic': tensor(16.8556, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(16.8556, device='cuda:0'),
#   'lasso_aic': tensor(21.9002, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(21.5623, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(16.8556, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(16.8556, device='cuda:0'),
#   'lasso_bic': tensor(21.9002, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(21.5623, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(16.8556, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(16.8556, device='cuda:0'),
#   'lasso_loocv': tensor(21.6187, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(21.5623, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=50_ρ=0.5_sparse': {'ridge_aic': tensor(0.0615, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(0.0615, device='cuda:0'),
#   'lasso_aic': tensor(0.1437, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(0.1669, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(0.0615, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(0.0615, device='cuda:0'),
#   'lasso_bic': tensor(0.1437, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(0.1669, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(0.0615, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(0.0615, device='cuda:0'),
#   'lasso_loocv': tensor(0.1316, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(0.1597, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=50_ρ=0.5_dense': {'ridge_aic': tensor(14.2813, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(14.2813, device='cuda:0'),
#   'lasso_aic': tensor(19.3557, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(18.8046, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(14.2813, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(14.2813, device='cuda:0'),
#   'lasso_bic': tensor(19.3557, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(18.8046, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(14.2813, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(14.2813, device='cuda:0'),
#   'lasso_loocv': tensor(19.0445, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(18.8046, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=25_ρ=0_sparse': {'ridge_aic': tensor(0.1451, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(0.1451, device='cuda:0'),
#   'lasso_aic': tensor(0.1680, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(0.1683, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(0.1451, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(0.1451, device='cuda:0'),
#   'lasso_bic': tensor(0.1680, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(0.1683, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(0.1451, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(0.1451, device='cuda:0'),
#   'lasso_loocv': tensor(0.1671, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(0.1644, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=25_ρ=0_dense': {'ridge_aic': tensor(17.7191, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(17.7191, device='cuda:0'),
#   'lasso_aic': tensor(21.7464, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(21.4606, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(17.7191, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(17.7191, device='cuda:0'),
#   'lasso_bic': tensor(21.7464, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(21.4606, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(17.7191, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(17.7191, device='cuda:0'),
#   'lasso_loocv': tensor(21.5295, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(21.4381, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=25_ρ=0.25_sparse': {'ridge_aic': tensor(0.1760, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(0.1760, device='cuda:0'),
#   'lasso_aic': tensor(0.2009, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(0.2024, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(0.1760, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(0.1760, device='cuda:0'),
#   'lasso_bic': tensor(0.2009, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(0.2024, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(0.1760, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(0.1760, device='cuda:0'),
#   'lasso_loocv': tensor(0.1989, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(0.1999, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=25_ρ=0.25_dense': {'ridge_aic': tensor(14.6512, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(14.6512, device='cuda:0'),
#   'lasso_aic': tensor(18.6939, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(18.4426, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(14.6512, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(14.6512, device='cuda:0'),
#   'lasso_bic': tensor(18.6939, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(18.4426, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(14.6512, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(14.6512, device='cuda:0'),
#   'lasso_loocv': tensor(18.4132, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(18.4280, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=25_ρ=0.5_sparse': {'ridge_aic': tensor(0.1572, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(0.1572, device='cuda:0'),
#   'lasso_aic': tensor(0.1804, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(0.1791, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(0.1572, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(0.1572, device='cuda:0'),
#   'lasso_bic': tensor(0.1804, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(0.1791, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(0.1572, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(0.1572, device='cuda:0'),
#   'lasso_loocv': tensor(0.1769, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(0.1754, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=25_ρ=0.5_dense': {'ridge_aic': tensor(21.4199, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(21.4199, device='cuda:0'),
#   'lasso_aic': tensor(25.6585, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(25.2796, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(21.4199, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(21.4199, device='cuda:0'),
#   'lasso_bic': tensor(25.6585, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(25.2796, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(21.4199, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(21.4199, device='cuda:0'),
#   'lasso_loocv': tensor(25.4382, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(25.2560, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=10_ρ=0_sparse': {'ridge_aic': tensor(0.2812, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(0.2812, device='cuda:0'),
#   'lasso_aic': tensor(0.2873, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(0.2890, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(0.2812, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(0.2812, device='cuda:0'),
#   'lasso_bic': tensor(0.2873, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(0.2890, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(0.2812, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(0.2812, device='cuda:0'),
#   'lasso_loocv': tensor(0.2876, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(0.2877, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=10_ρ=0_dense': {'ridge_aic': tensor(17.8453, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(17.8453, device='cuda:0'),
#   'lasso_aic': tensor(21.5131, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(21.3381, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(17.8453, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(17.8453, device='cuda:0'),
#   'lasso_bic': tensor(21.5131, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(21.3381, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(17.8453, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(17.8453, device='cuda:0'),
#   'lasso_loocv': tensor(21.2698, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(21.1600, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=10_ρ=0.25_sparse': {'ridge_aic': tensor(0.2612, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(0.2612, device='cuda:0'),
#   'lasso_aic': tensor(0.2697, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(0.2686, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(0.2612, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(0.2612, device='cuda:0'),
#   'lasso_bic': tensor(0.2697, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(0.2686, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(0.2612, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(0.2612, device='cuda:0'),
#   'lasso_loocv': tensor(0.2687, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(0.2671, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=10_ρ=0.25_dense': {'ridge_aic': tensor(15.7942, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(15.7942, device='cuda:0'),
#   'lasso_aic': tensor(19.5003, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(19.4312, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(15.7942, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(15.7942, device='cuda:0'),
#   'lasso_bic': tensor(19.5003, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(19.4312, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(15.7942, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(15.7942, device='cuda:0'),
#   'lasso_loocv': tensor(19.3697, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(19.1832, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=10_ρ=0.5_sparse': {'ridge_aic': tensor(0.2117, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(0.2117, device='cuda:0'),
#   'lasso_aic': tensor(0.2190, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(0.2191, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(0.2117, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(0.2117, device='cuda:0'),
#   'lasso_bic': tensor(0.2190, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(0.2191, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(0.2117, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(0.2117, device='cuda:0'),
#   'lasso_loocv': tensor(0.2189, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(0.2179, device='cuda:0', grad_fn=<MeanBackward0>)},
#  'n=100_p=10_ρ=0.5_dense': {'ridge_aic': tensor(17.5308, device='cuda:0'),
#   'ridge_adaptive_aic': tensor(17.5308, device='cuda:0'),
#   'lasso_aic': tensor(21.1763, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_aic': tensor(20.9192, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_bic': tensor(17.5308, device='cuda:0'),
#   'ridge_adaptive_bic': tensor(17.5308, device='cuda:0'),
#   'lasso_bic': tensor(21.1763, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_bic': tensor(20.9192, device='cuda:0', grad_fn=<MeanBackward0>),
#   'ridge_loocv': tensor(17.5308, device='cuda:0'),
#   'ridge_adaptive_loocv': tensor(17.5308, device='cuda:0'),
#   'lasso_loocv': tensor(20.9645, device='cuda:0', grad_fn=<MeanBackward0>),
#   'lasso_adaptive_loocv': tensor(20.7419, device='cuda:0', grad_fn=<MeanBackward0>)}}

# %%
import pandas as pd

df = pd.DataFrame(results)
df.to_csv('results.csv')
df
# Out:
#                                                   n=100_p=50_ρ=0_sparse  \
# ridge_aic                               tensor(0.0721, device='cuda:0')
# ridge_adaptive_aic                      tensor(0.0721, device='cuda:0')
# lasso_aic             tensor(0.1603, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_aic    tensor(0.1773, device='cuda:0', grad_fn=<MeanB...
# ridge_bic                               tensor(0.0721, device='cuda:0')
# ridge_adaptive_bic                      tensor(0.0721, device='cuda:0')
# lasso_bic             tensor(0.1603, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_bic    tensor(0.1773, device='cuda:0', grad_fn=<MeanB...
# ridge_loocv                             tensor(0.0721, device='cuda:0')
# ridge_adaptive_loocv                    tensor(0.0721, device='cuda:0')
# lasso_loocv           tensor(0.1463, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_loocv  tensor(0.1694, device='cuda:0', grad_fn=<MeanB...
#
#                                                    n=100_p=50_ρ=0_dense  \
# ridge_aic                              tensor(15.5376, device='cuda:0')
# ridge_adaptive_aic                     tensor(15.5376, device='cuda:0')
# lasso_aic             tensor(20.7056, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_aic    tensor(20.1790, device='cuda:0', grad_fn=<Mean...
# ridge_bic                              tensor(15.5376, device='cuda:0')
# ridge_adaptive_bic                     tensor(15.5376, device='cuda:0')
# lasso_bic             tensor(20.7056, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_bic    tensor(20.1790, device='cuda:0', grad_fn=<Mean...
# ridge_loocv                            tensor(15.5376, device='cuda:0')
# ridge_adaptive_loocv                   tensor(15.5376, device='cuda:0')
# lasso_loocv           tensor(20.4038, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_loocv  tensor(20.1790, device='cuda:0', grad_fn=<Mean...
#
#                                                n=100_p=50_ρ=0.25_sparse  \
# ridge_aic                               tensor(0.0629, device='cuda:0')
# ridge_adaptive_aic                      tensor(0.0629, device='cuda:0')
# lasso_aic             tensor(0.1465, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_aic    tensor(0.1688, device='cuda:0', grad_fn=<MeanB...
# ridge_bic                               tensor(0.0629, device='cuda:0')
# ridge_adaptive_bic                      tensor(0.0629, device='cuda:0')
# lasso_bic             tensor(0.1465, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_bic    tensor(0.1688, device='cuda:0', grad_fn=<MeanB...
# ridge_loocv                             tensor(0.0629, device='cuda:0')
# ridge_adaptive_loocv                    tensor(0.0629, device='cuda:0')
# lasso_loocv           tensor(0.1328, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_loocv  tensor(0.1605, device='cuda:0', grad_fn=<MeanB...
#
#                                                 n=100_p=50_ρ=0.25_dense  \
# ridge_aic                              tensor(16.8556, device='cuda:0')
# ridge_adaptive_aic                     tensor(16.8556, device='cuda:0')
# lasso_aic             tensor(21.9002, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_aic    tensor(21.5623, device='cuda:0', grad_fn=<Mean...
# ridge_bic                              tensor(16.8556, device='cuda:0')
# ridge_adaptive_bic                     tensor(16.8556, device='cuda:0')
# lasso_bic             tensor(21.9002, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_bic    tensor(21.5623, device='cuda:0', grad_fn=<Mean...
# ridge_loocv                            tensor(16.8556, device='cuda:0')
# ridge_adaptive_loocv                   tensor(16.8556, device='cuda:0')
# lasso_loocv           tensor(21.6187, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_loocv  tensor(21.5623, device='cuda:0', grad_fn=<Mean...
#
#                                                 n=100_p=50_ρ=0.5_sparse  \
# ridge_aic                               tensor(0.0615, device='cuda:0')
# ridge_adaptive_aic                      tensor(0.0615, device='cuda:0')
# lasso_aic             tensor(0.1437, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_aic    tensor(0.1669, device='cuda:0', grad_fn=<MeanB...
# ridge_bic                               tensor(0.0615, device='cuda:0')
# ridge_adaptive_bic                      tensor(0.0615, device='cuda:0')
# lasso_bic             tensor(0.1437, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_bic    tensor(0.1669, device='cuda:0', grad_fn=<MeanB...
# ridge_loocv                             tensor(0.0615, device='cuda:0')
# ridge_adaptive_loocv                    tensor(0.0615, device='cuda:0')
# lasso_loocv           tensor(0.1316, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_loocv  tensor(0.1597, device='cuda:0', grad_fn=<MeanB...
#
#                                                  n=100_p=50_ρ=0.5_dense  \
# ridge_aic                              tensor(14.2813, device='cuda:0')
# ridge_adaptive_aic                     tensor(14.2813, device='cuda:0')
# lasso_aic             tensor(19.3557, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_aic    tensor(18.8046, device='cuda:0', grad_fn=<Mean...
# ridge_bic                              tensor(14.2813, device='cuda:0')
# ridge_adaptive_bic                     tensor(14.2813, device='cuda:0')
# lasso_bic             tensor(19.3557, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_bic    tensor(18.8046, device='cuda:0', grad_fn=<Mean...
# ridge_loocv                            tensor(14.2813, device='cuda:0')
# ridge_adaptive_loocv                   tensor(14.2813, device='cuda:0')
# lasso_loocv           tensor(19.0445, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_loocv  tensor(18.8046, device='cuda:0', grad_fn=<Mean...
#
#                                                   n=100_p=25_ρ=0_sparse  \
# ridge_aic                               tensor(0.1451, device='cuda:0')
# ridge_adaptive_aic                      tensor(0.1451, device='cuda:0')
# lasso_aic             tensor(0.1680, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_aic    tensor(0.1683, device='cuda:0', grad_fn=<MeanB...
# ridge_bic                               tensor(0.1451, device='cuda:0')
# ridge_adaptive_bic                      tensor(0.1451, device='cuda:0')
# lasso_bic             tensor(0.1680, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_bic    tensor(0.1683, device='cuda:0', grad_fn=<MeanB...
# ridge_loocv                             tensor(0.1451, device='cuda:0')
# ridge_adaptive_loocv                    tensor(0.1451, device='cuda:0')
# lasso_loocv           tensor(0.1671, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_loocv  tensor(0.1644, device='cuda:0', grad_fn=<MeanB...
#
#                                                    n=100_p=25_ρ=0_dense  \
# ridge_aic                              tensor(17.7191, device='cuda:0')
# ridge_adaptive_aic                     tensor(17.7191, device='cuda:0')
# lasso_aic             tensor(21.7464, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_aic    tensor(21.4606, device='cuda:0', grad_fn=<Mean...
# ridge_bic                              tensor(17.7191, device='cuda:0')
# ridge_adaptive_bic                     tensor(17.7191, device='cuda:0')
# lasso_bic             tensor(21.7464, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_bic    tensor(21.4606, device='cuda:0', grad_fn=<Mean...
# ridge_loocv                            tensor(17.7191, device='cuda:0')
# ridge_adaptive_loocv                   tensor(17.7191, device='cuda:0')
# lasso_loocv           tensor(21.5295, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_loocv  tensor(21.4381, device='cuda:0', grad_fn=<Mean...
#
#                                                n=100_p=25_ρ=0.25_sparse  \
# ridge_aic                               tensor(0.1760, device='cuda:0')
# ridge_adaptive_aic                      tensor(0.1760, device='cuda:0')
# lasso_aic             tensor(0.2009, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_aic    tensor(0.2024, device='cuda:0', grad_fn=<MeanB...
# ridge_bic                               tensor(0.1760, device='cuda:0')
# ridge_adaptive_bic                      tensor(0.1760, device='cuda:0')
# lasso_bic             tensor(0.2009, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_bic    tensor(0.2024, device='cuda:0', grad_fn=<MeanB...
# ridge_loocv                             tensor(0.1760, device='cuda:0')
# ridge_adaptive_loocv                    tensor(0.1760, device='cuda:0')
# lasso_loocv           tensor(0.1989, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_loocv  tensor(0.1999, device='cuda:0', grad_fn=<MeanB...
#
#                                                 n=100_p=25_ρ=0.25_dense  \
# ridge_aic                              tensor(14.6512, device='cuda:0')
# ridge_adaptive_aic                     tensor(14.6512, device='cuda:0')
# lasso_aic             tensor(18.6939, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_aic    tensor(18.4426, device='cuda:0', grad_fn=<Mean...
# ridge_bic                              tensor(14.6512, device='cuda:0')
# ridge_adaptive_bic                     tensor(14.6512, device='cuda:0')
# lasso_bic             tensor(18.6939, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_bic    tensor(18.4426, device='cuda:0', grad_fn=<Mean...
# ridge_loocv                            tensor(14.6512, device='cuda:0')
# ridge_adaptive_loocv                   tensor(14.6512, device='cuda:0')
# lasso_loocv           tensor(18.4132, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_loocv  tensor(18.4280, device='cuda:0', grad_fn=<Mean...
#
#                                                 n=100_p=25_ρ=0.5_sparse  \
# ridge_aic                               tensor(0.1572, device='cuda:0')
# ridge_adaptive_aic                      tensor(0.1572, device='cuda:0')
# lasso_aic             tensor(0.1804, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_aic    tensor(0.1791, device='cuda:0', grad_fn=<MeanB...
# ridge_bic                               tensor(0.1572, device='cuda:0')
# ridge_adaptive_bic                      tensor(0.1572, device='cuda:0')
# lasso_bic             tensor(0.1804, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_bic    tensor(0.1791, device='cuda:0', grad_fn=<MeanB...
# ridge_loocv                             tensor(0.1572, device='cuda:0')
# ridge_adaptive_loocv                    tensor(0.1572, device='cuda:0')
# lasso_loocv           tensor(0.1769, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_loocv  tensor(0.1754, device='cuda:0', grad_fn=<MeanB...
#
#                                                  n=100_p=25_ρ=0.5_dense  \
# ridge_aic                              tensor(21.4199, device='cuda:0')
# ridge_adaptive_aic                     tensor(21.4199, device='cuda:0')
# lasso_aic             tensor(25.6585, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_aic    tensor(25.2796, device='cuda:0', grad_fn=<Mean...
# ridge_bic                              tensor(21.4199, device='cuda:0')
# ridge_adaptive_bic                     tensor(21.4199, device='cuda:0')
# lasso_bic             tensor(25.6585, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_bic    tensor(25.2796, device='cuda:0', grad_fn=<Mean...
# ridge_loocv                            tensor(21.4199, device='cuda:0')
# ridge_adaptive_loocv                   tensor(21.4199, device='cuda:0')
# lasso_loocv           tensor(25.4382, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_loocv  tensor(25.2560, device='cuda:0', grad_fn=<Mean...
#
#                                                   n=100_p=10_ρ=0_sparse  \
# ridge_aic                               tensor(0.2812, device='cuda:0')
# ridge_adaptive_aic                      tensor(0.2812, device='cuda:0')
# lasso_aic             tensor(0.2873, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_aic    tensor(0.2890, device='cuda:0', grad_fn=<MeanB...
# ridge_bic                               tensor(0.2812, device='cuda:0')
# ridge_adaptive_bic                      tensor(0.2812, device='cuda:0')
# lasso_bic             tensor(0.2873, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_bic    tensor(0.2890, device='cuda:0', grad_fn=<MeanB...
# ridge_loocv                             tensor(0.2812, device='cuda:0')
# ridge_adaptive_loocv                    tensor(0.2812, device='cuda:0')
# lasso_loocv           tensor(0.2876, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_loocv  tensor(0.2877, device='cuda:0', grad_fn=<MeanB...
#
#                                                    n=100_p=10_ρ=0_dense  \
# ridge_aic                              tensor(17.8453, device='cuda:0')
# ridge_adaptive_aic                     tensor(17.8453, device='cuda:0')
# lasso_aic             tensor(21.5131, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_aic    tensor(21.3381, device='cuda:0', grad_fn=<Mean...
# ridge_bic                              tensor(17.8453, device='cuda:0')
# ridge_adaptive_bic                     tensor(17.8453, device='cuda:0')
# lasso_bic             tensor(21.5131, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_bic    tensor(21.3381, device='cuda:0', grad_fn=<Mean...
# ridge_loocv                            tensor(17.8453, device='cuda:0')
# ridge_adaptive_loocv                   tensor(17.8453, device='cuda:0')
# lasso_loocv           tensor(21.2698, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_loocv  tensor(21.1600, device='cuda:0', grad_fn=<Mean...
#
#                                                n=100_p=10_ρ=0.25_sparse  \
# ridge_aic                               tensor(0.2612, device='cuda:0')
# ridge_adaptive_aic                      tensor(0.2612, device='cuda:0')
# lasso_aic             tensor(0.2697, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_aic    tensor(0.2686, device='cuda:0', grad_fn=<MeanB...
# ridge_bic                               tensor(0.2612, device='cuda:0')
# ridge_adaptive_bic                      tensor(0.2612, device='cuda:0')
# lasso_bic             tensor(0.2697, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_bic    tensor(0.2686, device='cuda:0', grad_fn=<MeanB...
# ridge_loocv                             tensor(0.2612, device='cuda:0')
# ridge_adaptive_loocv                    tensor(0.2612, device='cuda:0')
# lasso_loocv           tensor(0.2687, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_loocv  tensor(0.2671, device='cuda:0', grad_fn=<MeanB...
#
#                                                 n=100_p=10_ρ=0.25_dense  \
# ridge_aic                              tensor(15.7942, device='cuda:0')
# ridge_adaptive_aic                     tensor(15.7942, device='cuda:0')
# lasso_aic             tensor(19.5003, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_aic    tensor(19.4312, device='cuda:0', grad_fn=<Mean...
# ridge_bic                              tensor(15.7942, device='cuda:0')
# ridge_adaptive_bic                     tensor(15.7942, device='cuda:0')
# lasso_bic             tensor(19.5003, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_bic    tensor(19.4312, device='cuda:0', grad_fn=<Mean...
# ridge_loocv                            tensor(15.7942, device='cuda:0')
# ridge_adaptive_loocv                   tensor(15.7942, device='cuda:0')
# lasso_loocv           tensor(19.3697, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_loocv  tensor(19.1832, device='cuda:0', grad_fn=<Mean...
#
#                                                 n=100_p=10_ρ=0.5_sparse  \
# ridge_aic                               tensor(0.2117, device='cuda:0')
# ridge_adaptive_aic                      tensor(0.2117, device='cuda:0')
# lasso_aic             tensor(0.2190, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_aic    tensor(0.2191, device='cuda:0', grad_fn=<MeanB...
# ridge_bic                               tensor(0.2117, device='cuda:0')
# ridge_adaptive_bic                      tensor(0.2117, device='cuda:0')
# lasso_bic             tensor(0.2190, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_bic    tensor(0.2191, device='cuda:0', grad_fn=<MeanB...
# ridge_loocv                             tensor(0.2117, device='cuda:0')
# ridge_adaptive_loocv                    tensor(0.2117, device='cuda:0')
# lasso_loocv           tensor(0.2189, device='cuda:0', grad_fn=<MeanB...
# lasso_adaptive_loocv  tensor(0.2179, device='cuda:0', grad_fn=<MeanB...
#
#                                                  n=100_p=10_ρ=0.5_dense
# ridge_aic                              tensor(17.5308, device='cuda:0')
# ridge_adaptive_aic                     tensor(17.5308, device='cuda:0')
# lasso_aic             tensor(21.1763, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_aic    tensor(20.9192, device='cuda:0', grad_fn=<Mean...
# ridge_bic                              tensor(17.5308, device='cuda:0')
# ridge_adaptive_bic                     tensor(17.5308, device='cuda:0')
# lasso_bic             tensor(21.1763, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_bic    tensor(20.9192, device='cuda:0', grad_fn=<Mean...
# ridge_loocv                            tensor(17.5308, device='cuda:0')
# ridge_adaptive_loocv                   tensor(17.5308, device='cuda:0')
# lasso_loocv           tensor(20.9645, device='cuda:0', grad_fn=<Mean...
# lasso_adaptive_loocv  tensor(20.7419, device='cuda:0', grad_fn=<Mean...

# %%
new_results = {
    k:{k1:v1.item() for k1,v1 in v.items()} for k,v in results.items()
}

# %%
new_results
# Out:
# {'n=100_p=50_ρ=0_sparse': {'ridge_aic': 0.07209954410791397,
#   'ridge_adaptive_aic': 0.07209954410791397,
#   'lasso_aic': 0.16029036045074463,
#   'lasso_adaptive_aic': 0.177296444773674,
#   'ridge_bic': 0.07209954410791397,
#   'ridge_adaptive_bic': 0.07209954410791397,
#   'lasso_bic': 0.16029036045074463,
#   'lasso_adaptive_bic': 0.177296444773674,
#   'ridge_loocv': 0.07209954410791397,
#   'ridge_adaptive_loocv': 0.07209954410791397,
#   'lasso_loocv': 0.14632420241832733,
#   'lasso_adaptive_loocv': 0.1693868190050125},
#  'n=100_p=50_ρ=0_dense': {'ridge_aic': 15.537561416625977,
#   'ridge_adaptive_aic': 15.537561416625977,
#   'lasso_aic': 20.705595016479492,
#   'lasso_adaptive_aic': 20.179044723510742,
#   'ridge_bic': 15.537561416625977,
#   'ridge_adaptive_bic': 15.537561416625977,
#   'lasso_bic': 20.705595016479492,
#   'lasso_adaptive_bic': 20.179044723510742,
#   'ridge_loocv': 15.537561416625977,
#   'ridge_adaptive_loocv': 15.537561416625977,
#   'lasso_loocv': 20.40380096435547,
#   'lasso_adaptive_loocv': 20.179044723510742},
#  'n=100_p=50_ρ=0.25_sparse': {'ridge_aic': 0.06294110417366028,
#   'ridge_adaptive_aic': 0.06294110417366028,
#   'lasso_aic': 0.1464962661266327,
#   'lasso_adaptive_aic': 0.16877125203609467,
#   'ridge_bic': 0.06294110417366028,
#   'ridge_adaptive_bic': 0.06294110417366028,
#   'lasso_bic': 0.1464962661266327,
#   'lasso_adaptive_bic': 0.16877125203609467,
#   'ridge_loocv': 0.06294110417366028,
#   'ridge_adaptive_loocv': 0.06294110417366028,
#   'lasso_loocv': 0.13281530141830444,
#   'lasso_adaptive_loocv': 0.1605379730463028},
#  'n=100_p=50_ρ=0.25_dense': {'ridge_aic': 16.855609893798828,
#   'ridge_adaptive_aic': 16.855609893798828,
#   'lasso_aic': 21.90018653869629,
#   'lasso_adaptive_aic': 21.562301635742188,
#   'ridge_bic': 16.855609893798828,
#   'ridge_adaptive_bic': 16.855609893798828,
#   'lasso_bic': 21.90018653869629,
#   'lasso_adaptive_bic': 21.562301635742188,
#   'ridge_loocv': 16.855609893798828,
#   'ridge_adaptive_loocv': 16.855609893798828,
#   'lasso_loocv': 21.618694305419922,
#   'lasso_adaptive_loocv': 21.562301635742188},
#  'n=100_p=50_ρ=0.5_sparse': {'ridge_aic': 0.06146719306707382,
#   'ridge_adaptive_aic': 0.06146719306707382,
#   'lasso_aic': 0.14373725652694702,
#   'lasso_adaptive_aic': 0.16690298914909363,
#   'ridge_bic': 0.06146719306707382,
#   'ridge_adaptive_bic': 0.06146719306707382,
#   'lasso_bic': 0.14373725652694702,
#   'lasso_adaptive_bic': 0.16690298914909363,
#   'ridge_loocv': 0.06146719306707382,
#   'ridge_adaptive_loocv': 0.06146719306707382,
#   'lasso_loocv': 0.13155990839004517,
#   'lasso_adaptive_loocv': 0.1597207486629486},
#  'n=100_p=50_ρ=0.5_dense': {'ridge_aic': 14.281296730041504,
#   'ridge_adaptive_aic': 14.281296730041504,
#   'lasso_aic': 19.35569190979004,
#   'lasso_adaptive_aic': 18.80455780029297,
#   'ridge_bic': 14.281296730041504,
#   'ridge_adaptive_bic': 14.281296730041504,
#   'lasso_bic': 19.35569190979004,
#   'lasso_adaptive_bic': 18.80455780029297,
#   'ridge_loocv': 14.281296730041504,
#   'ridge_adaptive_loocv': 14.281296730041504,
#   'lasso_loocv': 19.044525146484375,
#   'lasso_adaptive_loocv': 18.80455780029297},
#  'n=100_p=25_ρ=0_sparse': {'ridge_aic': 0.14505013823509216,
#   'ridge_adaptive_aic': 0.14505013823509216,
#   'lasso_aic': 0.1679745614528656,
#   'lasso_adaptive_aic': 0.16833683848381042,
#   'ridge_bic': 0.14505013823509216,
#   'ridge_adaptive_bic': 0.14505013823509216,
#   'lasso_bic': 0.1679745614528656,
#   'lasso_adaptive_bic': 0.16833683848381042,
#   'ridge_loocv': 0.14505013823509216,
#   'ridge_adaptive_loocv': 0.14505013823509216,
#   'lasso_loocv': 0.16709938645362854,
#   'lasso_adaptive_loocv': 0.16444386541843414},
#  'n=100_p=25_ρ=0_dense': {'ridge_aic': 17.71910285949707,
#   'ridge_adaptive_aic': 17.71910285949707,
#   'lasso_aic': 21.74639320373535,
#   'lasso_adaptive_aic': 21.460559844970703,
#   'ridge_bic': 17.71910285949707,
#   'ridge_adaptive_bic': 17.71910285949707,
#   'lasso_bic': 21.74639320373535,
#   'lasso_adaptive_bic': 21.460559844970703,
#   'ridge_loocv': 17.71910285949707,
#   'ridge_adaptive_loocv': 17.71910285949707,
#   'lasso_loocv': 21.529516220092773,
#   'lasso_adaptive_loocv': 21.4381103515625},
#  'n=100_p=25_ρ=0.25_sparse': {'ridge_aic': 0.1759832501411438,
#   'ridge_adaptive_aic': 0.1759832501411438,
#   'lasso_aic': 0.20092499256134033,
#   'lasso_adaptive_aic': 0.2023518830537796,
#   'ridge_bic': 0.1759832501411438,
#   'ridge_adaptive_bic': 0.1759832501411438,
#   'lasso_bic': 0.20092499256134033,
#   'lasso_adaptive_bic': 0.2023518830537796,
#   'ridge_loocv': 0.1759832501411438,
#   'ridge_adaptive_loocv': 0.1759832501411438,
#   'lasso_loocv': 0.19891025125980377,
#   'lasso_adaptive_loocv': 0.199880450963974},
#  'n=100_p=25_ρ=0.25_dense': {'ridge_aic': 14.651214599609375,
#   'ridge_adaptive_aic': 14.651214599609375,
#   'lasso_aic': 18.69391441345215,
#   'lasso_adaptive_aic': 18.442567825317383,
#   'ridge_bic': 14.651214599609375,
#   'ridge_adaptive_bic': 14.651214599609375,
#   'lasso_bic': 18.69391441345215,
#   'lasso_adaptive_bic': 18.442567825317383,
#   'ridge_loocv': 14.651214599609375,
#   'ridge_adaptive_loocv': 14.651214599609375,
#   'lasso_loocv': 18.413188934326172,
#   'lasso_adaptive_loocv': 18.4279727935791},
#  'n=100_p=25_ρ=0.5_sparse': {'ridge_aic': 0.15717804431915283,
#   'ridge_adaptive_aic': 0.15717804431915283,
#   'lasso_aic': 0.18036936223506927,
#   'lasso_adaptive_aic': 0.17914335429668427,
#   'ridge_bic': 0.15717804431915283,
#   'ridge_adaptive_bic': 0.15717804431915283,
#   'lasso_bic': 0.18036936223506927,
#   'lasso_adaptive_bic': 0.17914335429668427,
#   'ridge_loocv': 0.15717804431915283,
#   'ridge_adaptive_loocv': 0.15717804431915283,
#   'lasso_loocv': 0.1769109070301056,
#   'lasso_adaptive_loocv': 0.1753578931093216},
#  'n=100_p=25_ρ=0.5_dense': {'ridge_aic': 21.419931411743164,
#   'ridge_adaptive_aic': 21.419931411743164,
#   'lasso_aic': 25.658451080322266,
#   'lasso_adaptive_aic': 25.27956199645996,
#   'ridge_bic': 21.419931411743164,
#   'ridge_adaptive_bic': 21.419931411743164,
#   'lasso_bic': 25.658451080322266,
#   'lasso_adaptive_bic': 25.27956199645996,
#   'ridge_loocv': 21.419931411743164,
#   'ridge_adaptive_loocv': 21.419931411743164,
#   'lasso_loocv': 25.43821907043457,
#   'lasso_adaptive_loocv': 25.25599479675293},
#  'n=100_p=10_ρ=0_sparse': {'ridge_aic': 0.2811726927757263,
#   'ridge_adaptive_aic': 0.2811726927757263,
#   'lasso_aic': 0.28733113408088684,
#   'lasso_adaptive_aic': 0.2889861464500427,
#   'ridge_bic': 0.2811726927757263,
#   'ridge_adaptive_bic': 0.2811726927757263,
#   'lasso_bic': 0.28733113408088684,
#   'lasso_adaptive_bic': 0.2889861464500427,
#   'ridge_loocv': 0.2811726927757263,
#   'ridge_adaptive_loocv': 0.2811726927757263,
#   'lasso_loocv': 0.28757673501968384,
#   'lasso_adaptive_loocv': 0.2876671850681305},
#  'n=100_p=10_ρ=0_dense': {'ridge_aic': 17.8453369140625,
#   'ridge_adaptive_aic': 17.8453369140625,
#   'lasso_aic': 21.513050079345703,
#   'lasso_adaptive_aic': 21.338071823120117,
#   'ridge_bic': 17.8453369140625,
#   'ridge_adaptive_bic': 17.8453369140625,
#   'lasso_bic': 21.513050079345703,
#   'lasso_adaptive_bic': 21.338071823120117,
#   'ridge_loocv': 17.8453369140625,
#   'ridge_adaptive_loocv': 17.8453369140625,
#   'lasso_loocv': 21.26982307434082,
#   'lasso_adaptive_loocv': 21.15995979309082},
#  'n=100_p=10_ρ=0.25_sparse': {'ridge_aic': 0.26123979687690735,
#   'ridge_adaptive_aic': 0.26123979687690735,
#   'lasso_aic': 0.26966533064842224,
#   'lasso_adaptive_aic': 0.2685600817203522,
#   'ridge_bic': 0.26123979687690735,
#   'ridge_adaptive_bic': 0.26123979687690735,
#   'lasso_bic': 0.26966533064842224,
#   'lasso_adaptive_bic': 0.2685600817203522,
#   'ridge_loocv': 0.26123979687690735,
#   'ridge_adaptive_loocv': 0.26123979687690735,
#   'lasso_loocv': 0.2687101662158966,
#   'lasso_adaptive_loocv': 0.2670753002166748},
#  'n=100_p=10_ρ=0.25_dense': {'ridge_aic': 15.794200897216797,
#   'ridge_adaptive_aic': 15.794200897216797,
#   'lasso_aic': 19.500268936157227,
#   'lasso_adaptive_aic': 19.431222915649414,
#   'ridge_bic': 15.794200897216797,
#   'ridge_adaptive_bic': 15.794200897216797,
#   'lasso_bic': 19.500268936157227,
#   'lasso_adaptive_bic': 19.431222915649414,
#   'ridge_loocv': 15.794200897216797,
#   'ridge_adaptive_loocv': 15.794200897216797,
#   'lasso_loocv': 19.36972427368164,
#   'lasso_adaptive_loocv': 19.18319320678711},
#  'n=100_p=10_ρ=0.5_sparse': {'ridge_aic': 0.21173623204231262,
#   'ridge_adaptive_aic': 0.21173623204231262,
#   'lasso_aic': 0.2190026342868805,
#   'lasso_adaptive_aic': 0.21912892162799835,
#   'ridge_bic': 0.21173623204231262,
#   'ridge_adaptive_bic': 0.21173623204231262,
#   'lasso_bic': 0.2190026342868805,
#   'lasso_adaptive_bic': 0.21912892162799835,
#   'ridge_loocv': 0.21173623204231262,
#   'ridge_adaptive_loocv': 0.21173623204231262,
#   'lasso_loocv': 0.21885566413402557,
#   'lasso_adaptive_loocv': 0.21794331073760986},
#  'n=100_p=10_ρ=0.5_dense': {'ridge_aic': 17.530773162841797,
#   'ridge_adaptive_aic': 17.530773162841797,
#   'lasso_aic': 21.176250457763672,
#   'lasso_adaptive_aic': 20.919160842895508,
#   'ridge_bic': 17.530773162841797,
#   'ridge_adaptive_bic': 17.530773162841797,
#   'lasso_bic': 21.176250457763672,
#   'lasso_adaptive_bic': 20.919160842895508,
#   'ridge_loocv': 17.530773162841797,
#   'ridge_adaptive_loocv': 17.530773162841797,
#   'lasso_loocv': 20.964508056640625,
#   'lasso_adaptive_loocv': 20.74192237854004}}

# %%
new_df = pd.DataFrame(new_results)

# %%
new_df.to_csv('results.csv')

# %%
new_df
# Out:
#                       n=100_p=50_ρ=0_sparse  n=100_p=50_ρ=0_dense  \
# ridge_aic                          0.072100             15.537561
# ridge_adaptive_aic                 0.072100             15.537561
# lasso_aic                          0.160290             20.705595
# lasso_adaptive_aic                 0.177296             20.179045
# ridge_bic                          0.072100             15.537561
# ridge_adaptive_bic                 0.072100             15.537561
# lasso_bic                          0.160290             20.705595
# lasso_adaptive_bic                 0.177296             20.179045
# ridge_loocv                        0.072100             15.537561
# ridge_adaptive_loocv               0.072100             15.537561
# lasso_loocv                        0.146324             20.403801
# lasso_adaptive_loocv               0.169387             20.179045
#
#                       n=100_p=50_ρ=0.25_sparse  n=100_p=50_ρ=0.25_dense  \
# ridge_aic                             0.062941                16.855610
# ridge_adaptive_aic                    0.062941                16.855610
# lasso_aic                             0.146496                21.900187
# lasso_adaptive_aic                    0.168771                21.562302
# ridge_bic                             0.062941                16.855610
# ridge_adaptive_bic                    0.062941                16.855610
# lasso_bic                             0.146496                21.900187
# lasso_adaptive_bic                    0.168771                21.562302
# ridge_loocv                           0.062941                16.855610
# ridge_adaptive_loocv                  0.062941                16.855610
# lasso_loocv                           0.132815                21.618694
# lasso_adaptive_loocv                  0.160538                21.562302
#
#                       n=100_p=50_ρ=0.5_sparse  n=100_p=50_ρ=0.5_dense  \
# ridge_aic                            0.061467               14.281297
# ridge_adaptive_aic                   0.061467               14.281297
# lasso_aic                            0.143737               19.355692
# lasso_adaptive_aic                   0.166903               18.804558
# ridge_bic                            0.061467               14.281297
# ridge_adaptive_bic                   0.061467               14.281297
# lasso_bic                            0.143737               19.355692
# lasso_adaptive_bic                   0.166903               18.804558
# ridge_loocv                          0.061467               14.281297
# ridge_adaptive_loocv                 0.061467               14.281297
# lasso_loocv                          0.131560               19.044525
# lasso_adaptive_loocv                 0.159721               18.804558
#
#                       n=100_p=25_ρ=0_sparse  n=100_p=25_ρ=0_dense  \
# ridge_aic                          0.145050             17.719103
# ridge_adaptive_aic                 0.145050             17.719103
# lasso_aic                          0.167975             21.746393
# lasso_adaptive_aic                 0.168337             21.460560
# ridge_bic                          0.145050             17.719103
# ridge_adaptive_bic                 0.145050             17.719103
# lasso_bic                          0.167975             21.746393
# lasso_adaptive_bic                 0.168337             21.460560
# ridge_loocv                        0.145050             17.719103
# ridge_adaptive_loocv               0.145050             17.719103
# lasso_loocv                        0.167099             21.529516
# lasso_adaptive_loocv               0.164444             21.438110
#
#                       n=100_p=25_ρ=0.25_sparse  n=100_p=25_ρ=0.25_dense  \
# ridge_aic                             0.175983                14.651215
# ridge_adaptive_aic                    0.175983                14.651215
# lasso_aic                             0.200925                18.693914
# lasso_adaptive_aic                    0.202352                18.442568
# ridge_bic                             0.175983                14.651215
# ridge_adaptive_bic                    0.175983                14.651215
# lasso_bic                             0.200925                18.693914
# lasso_adaptive_bic                    0.202352                18.442568
# ridge_loocv                           0.175983                14.651215
# ridge_adaptive_loocv                  0.175983                14.651215
# lasso_loocv                           0.198910                18.413189
# lasso_adaptive_loocv                  0.199880                18.427973
#
#                       n=100_p=25_ρ=0.5_sparse  n=100_p=25_ρ=0.5_dense  \
# ridge_aic                            0.157178               21.419931
# ridge_adaptive_aic                   0.157178               21.419931
# lasso_aic                            0.180369               25.658451
# lasso_adaptive_aic                   0.179143               25.279562
# ridge_bic                            0.157178               21.419931
# ridge_adaptive_bic                   0.157178               21.419931
# lasso_bic                            0.180369               25.658451
# lasso_adaptive_bic                   0.179143               25.279562
# ridge_loocv                          0.157178               21.419931
# ridge_adaptive_loocv                 0.157178               21.419931
# lasso_loocv                          0.176911               25.438219
# lasso_adaptive_loocv                 0.175358               25.255995
#
#                       n=100_p=10_ρ=0_sparse  n=100_p=10_ρ=0_dense  \
# ridge_aic                          0.281173             17.845337
# ridge_adaptive_aic                 0.281173             17.845337
# lasso_aic                          0.287331             21.513050
# lasso_adaptive_aic                 0.288986             21.338072
# ridge_bic                          0.281173             17.845337
# ridge_adaptive_bic                 0.281173             17.845337
# lasso_bic                          0.287331             21.513050
# lasso_adaptive_bic                 0.288986             21.338072
# ridge_loocv                        0.281173             17.845337
# ridge_adaptive_loocv               0.281173             17.845337
# lasso_loocv                        0.287577             21.269823
# lasso_adaptive_loocv               0.287667             21.159960
#
#                       n=100_p=10_ρ=0.25_sparse  n=100_p=10_ρ=0.25_dense  \
# ridge_aic                             0.261240                15.794201
# ridge_adaptive_aic                    0.261240                15.794201
# lasso_aic                             0.269665                19.500269
# lasso_adaptive_aic                    0.268560                19.431223
# ridge_bic                             0.261240                15.794201
# ridge_adaptive_bic                    0.261240                15.794201
# lasso_bic                             0.269665                19.500269
# lasso_adaptive_bic                    0.268560                19.431223
# ridge_loocv                           0.261240                15.794201
# ridge_adaptive_loocv                  0.261240                15.794201
# lasso_loocv                           0.268710                19.369724
# lasso_adaptive_loocv                  0.267075                19.183193
#
#                       n=100_p=10_ρ=0.5_sparse  n=100_p=10_ρ=0.5_dense
# ridge_aic                            0.211736               17.530773
# ridge_adaptive_aic                   0.211736               17.530773
# lasso_aic                            0.219003               21.176250
# lasso_adaptive_aic                   0.219129               20.919161
# ridge_bic                            0.211736               17.530773
# ridge_adaptive_bic                   0.211736               17.530773
# lasso_bic                            0.219003               21.176250
# lasso_adaptive_bic                   0.219129               20.919161
# ridge_loocv                          0.211736               17.530773
# ridge_adaptive_loocv                 0.211736               17.530773
# lasso_loocv                          0.218856               20.964508
# lasso_adaptive_loocv                 0.217943               20.741922

# %%
pd.set_option('display.precision', 4)
new_df
# Out:
#                       n=100_p=50_ρ=0_sparse  n=100_p=50_ρ=0_dense  \
# ridge_aic                            0.0721               15.5376
# ridge_adaptive_aic                   0.0721               15.5376
# lasso_aic                            0.1603               20.7056
# lasso_adaptive_aic                   0.1773               20.1790
# ridge_bic                            0.0721               15.5376
# ridge_adaptive_bic                   0.0721               15.5376
# lasso_bic                            0.1603               20.7056
# lasso_adaptive_bic                   0.1773               20.1790
# ridge_loocv                          0.0721               15.5376
# ridge_adaptive_loocv                 0.0721               15.5376
# lasso_loocv                          0.1463               20.4038
# lasso_adaptive_loocv                 0.1694               20.1790
#
#                       n=100_p=50_ρ=0.25_sparse  n=100_p=50_ρ=0.25_dense  \
# ridge_aic                               0.0629                  16.8556
# ridge_adaptive_aic                      0.0629                  16.8556
# lasso_aic                               0.1465                  21.9002
# lasso_adaptive_aic                      0.1688                  21.5623
# ridge_bic                               0.0629                  16.8556
# ridge_adaptive_bic                      0.0629                  16.8556
# lasso_bic                               0.1465                  21.9002
# lasso_adaptive_bic                      0.1688                  21.5623
# ridge_loocv                             0.0629                  16.8556
# ridge_adaptive_loocv                    0.0629                  16.8556
# lasso_loocv                             0.1328                  21.6187
# lasso_adaptive_loocv                    0.1605                  21.5623
#
#                       n=100_p=50_ρ=0.5_sparse  n=100_p=50_ρ=0.5_dense  \
# ridge_aic                              0.0615                 14.2813
# ridge_adaptive_aic                     0.0615                 14.2813
# lasso_aic                              0.1437                 19.3557
# lasso_adaptive_aic                     0.1669                 18.8046
# ridge_bic                              0.0615                 14.2813
# ridge_adaptive_bic                     0.0615                 14.2813
# lasso_bic                              0.1437                 19.3557
# lasso_adaptive_bic                     0.1669                 18.8046
# ridge_loocv                            0.0615                 14.2813
# ridge_adaptive_loocv                   0.0615                 14.2813
# lasso_loocv                            0.1316                 19.0445
# lasso_adaptive_loocv                   0.1597                 18.8046
#
#                       n=100_p=25_ρ=0_sparse  n=100_p=25_ρ=0_dense  \
# ridge_aic                            0.1451               17.7191
# ridge_adaptive_aic                   0.1451               17.7191
# lasso_aic                            0.1680               21.7464
# lasso_adaptive_aic                   0.1683               21.4606
# ridge_bic                            0.1451               17.7191
# ridge_adaptive_bic                   0.1451               17.7191
# lasso_bic                            0.1680               21.7464
# lasso_adaptive_bic                   0.1683               21.4606
# ridge_loocv                          0.1451               17.7191
# ridge_adaptive_loocv                 0.1451               17.7191
# lasso_loocv                          0.1671               21.5295
# lasso_adaptive_loocv                 0.1644               21.4381
#
#                       n=100_p=25_ρ=0.25_sparse  n=100_p=25_ρ=0.25_dense  \
# ridge_aic                               0.1760                  14.6512
# ridge_adaptive_aic                      0.1760                  14.6512
# lasso_aic                               0.2009                  18.6939
# lasso_adaptive_aic                      0.2024                  18.4426
# ridge_bic                               0.1760                  14.6512
# ridge_adaptive_bic                      0.1760                  14.6512
# lasso_bic                               0.2009                  18.6939
# lasso_adaptive_bic                      0.2024                  18.4426
# ridge_loocv                             0.1760                  14.6512
# ridge_adaptive_loocv                    0.1760                  14.6512
# lasso_loocv                             0.1989                  18.4132
# lasso_adaptive_loocv                    0.1999                  18.4280
#
#                       n=100_p=25_ρ=0.5_sparse  n=100_p=25_ρ=0.5_dense  \
# ridge_aic                              0.1572                 21.4199
# ridge_adaptive_aic                     0.1572                 21.4199
# lasso_aic                              0.1804                 25.6585
# lasso_adaptive_aic                     0.1791                 25.2796
# ridge_bic                              0.1572                 21.4199
# ridge_adaptive_bic                     0.1572                 21.4199
# lasso_bic                              0.1804                 25.6585
# lasso_adaptive_bic                     0.1791                 25.2796
# ridge_loocv                            0.1572                 21.4199
# ridge_adaptive_loocv                   0.1572                 21.4199
# lasso_loocv                            0.1769                 25.4382
# lasso_adaptive_loocv                   0.1754                 25.2560
#
#                       n=100_p=10_ρ=0_sparse  n=100_p=10_ρ=0_dense  \
# ridge_aic                            0.2812               17.8453
# ridge_adaptive_aic                   0.2812               17.8453
# lasso_aic                            0.2873               21.5131
# lasso_adaptive_aic                   0.2890               21.3381
# ridge_bic                            0.2812               17.8453
# ridge_adaptive_bic                   0.2812               17.8453
# lasso_bic                            0.2873               21.5131
# lasso_adaptive_bic                   0.2890               21.3381
# ridge_loocv                          0.2812               17.8453
# ridge_adaptive_loocv                 0.2812               17.8453
# lasso_loocv                          0.2876               21.2698
# lasso_adaptive_loocv                 0.2877               21.1600
#
#                       n=100_p=10_ρ=0.25_sparse  n=100_p=10_ρ=0.25_dense  \
# ridge_aic                               0.2612                  15.7942
# ridge_adaptive_aic                      0.2612                  15.7942
# lasso_aic                               0.2697                  19.5003
# lasso_adaptive_aic                      0.2686                  19.4312
# ridge_bic                               0.2612                  15.7942
# ridge_adaptive_bic                      0.2612                  15.7942
# lasso_bic                               0.2697                  19.5003
# lasso_adaptive_bic                      0.2686                  19.4312
# ridge_loocv                             0.2612                  15.7942
# ridge_adaptive_loocv                    0.2612                  15.7942
# lasso_loocv                             0.2687                  19.3697
# lasso_adaptive_loocv                    0.2671                  19.1832
#
#                       n=100_p=10_ρ=0.5_sparse  n=100_p=10_ρ=0.5_dense
# ridge_aic                              0.2117                 17.5308
# ridge_adaptive_aic                     0.2117                 17.5308
# lasso_aic                              0.2190                 21.1763
# lasso_adaptive_aic                     0.2191                 20.9192
# ridge_bic                              0.2117                 17.5308
# ridge_adaptive_bic                     0.2117                 17.5308
# lasso_bic                              0.2190                 21.1763
# lasso_adaptive_bic                     0.2191                 20.9192
# ridge_loocv                            0.2117                 17.5308
# ridge_adaptive_loocv                   0.2117                 17.5308
# lasso_loocv                            0.2189                 20.9645
# lasso_adaptive_loocv                   0.2179                 20.7419
